# %%
import imageio
import torch
img_arr = imageio.imread(r"C:\Users\Admin\Desktop\tp3security\baboon.png")
img_arr.shape
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_47388\3286259119.py:3: DeprecationWarning: Starting with ImageIO v3 the behavior of this function will switch to that of iio.v3.imread. To keep the current behavior (and make this warning disappear) use `import imageio.v2 as imageio` or call `imageio.v2.imread` directly.
#   img_arr = imageio.imread(r"C:\Users\Admin\Desktop\tp3security\baboon.png")
# (512, 512, 3)

# %%
img = torch.from_numpy(img_arr)
out = img.permute(2,0,1)
out.shape
# Out:
# torch.Size([3, 512, 512])

# %%
batch_size = 3
batch = torch.zeros(batch_size, 3, 256, 256, dtype = torch.uint8)

# %%
import os 
from torchvision import transforms
resize = transforms.Resize((256,256))
dir = r"C:\Users\Admin\Desktop\cats"
filenames = []
for name in os.listdir(dir):
    if name.endswith(".png"):
        filenames.append(name)

for i , filename in enumerate (filenames):
    img_arr = imageio.imread(os.path.join(dir, filename))
    img_t = torch.from_numpy(img_arr)
    img_t = img_t.permute(2,0,1)
    img_t = img_t[:3]
    img_t = resize(img_t)
    batch[i] = img_t
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_47388\1296410881.py:11: DeprecationWarning: Starting with ImageIO v3 the behavior of this function will switch to that of iio.v3.imread. To keep the current behavior (and make this warning disappear) use `import imageio.v2 as imageio` or call `imageio.v2.imread` directly.
#   img_arr = imageio.imread(os.path.join(dir, filename))
# c:\Users\Admin\anaconda3\envs\pytorch_env\lib\site-packages\PIL\Image.py:1039: UserWarning: Palette images with Transparency expressed in bytes should be converted to RGBA images
#   warnings.warn(

# %%
batch = batch.float()
batch = batch / 255.0

# %%
n_channels = batch.shape[1]
for c in range (n_channels):
    mean = torch.mean(batch[:, c])
    std = torch.std(batch[:, c])
    batch[:, c] = (batch[:, c] - mean ) / std

# %%
dir_path = r"C:\Users\Admin\Downloads\000000.dcm"
vol_arr = imageio.volread(dir_path, 'DICOM')
vol_arr.shape
# Out:
# Reading DICOM (examining files): 1/58493 files (0.09/58493 files (0.016/58493 files (0.0%20/58493 files (0.0%29/58493 files (0.0%33/58493 files (0.1%43/58493 files (0.1%45/58493 files (0.1%48/58493 files (0.1%50/58493 files (0.1%54/58493 files (0.1%57/58493 files (0.1%62/58493 files (0.1%68/58493 files (0.1%75/58493 files (0.1%80/58493 files (0.1%89/58493 files (0.2%100/58493 files (0.2109/58493 files (0.2112/58493 files (0.2120/58493 files (0.2124/58493 files (0.2125/58493 files (0.2129/58493 files (0.2140/58493 files (0.2145/58493 files (0.2153/58493 files (0.3160/58493 files (0.3166/58493 files (0.3174/58493 files (0.3182/58493 files (0.3188/58493 files (0.3196/58493 files (0.3197/58493 files (0.3199/58493 files (0.3200/58493 files (0.3201/58493 files (0.3202/58493 files (0.3210/58493 files (0.4216/58493 files (0.4225/58493 files (0.4232/58493 files (0.4238/58493 files (0.4244/58493 files (0.4252/58493 files (0.4258/58493 files (0.4266/58493 files (0.5273/58493 files (0.5279/58493
# ...

# %%
vol = torch.from_numpy(vol_arr).float()
vol = torch.unsqueeze(vol , 0)
vol.shape
# Out:
# torch.Size([1, 512, 512])

# %%
import csv 
import numpy as np
wine_path = r"C:\Users\Admin\Desktop\dl-pytorch\winequality-white.csv"
wine_arr = np.loadtxt(wine_path, dtype = np.float32, delimiter= ";", skiprows=1)
wine_arr
# Out:
# array([[ 7.  ,  0.27,  0.36, ...,  0.45,  8.8 ,  6.  ],
#        [ 6.3 ,  0.3 ,  0.34, ...,  0.49,  9.5 ,  6.  ],
#        [ 8.1 ,  0.28,  0.4 , ...,  0.44, 10.1 ,  6.  ],
#        ...,
#        [ 6.5 ,  0.24,  0.19, ...,  0.46,  9.4 ,  6.  ],
#        [ 5.5 ,  0.29,  0.3 , ...,  0.38, 12.8 ,  7.  ],
#        [ 6.  ,  0.21,  0.38, ...,  0.32, 11.8 ,  6.  ]],
#       shape=(4898, 12), dtype=float32)

# %%
col_list = next(csv.reader(open(wine_path), delimiter=';'))
col_list
# Out:
# ['fixed acidity',
#  'volatile acidity',
#  'citric acid',
#  'residual sugar',
#  'chlorides',
#  'free sulfur dioxide',
#  'total sulfur dioxide',
#  'density',
#  'pH',
#  'sulphates',
#  'alcohol',
#  'quality']

# %%
wine = torch.from_numpy(wine_arr)
wine.shape , wine.dtype
# Out:
# (torch.Size([4898, 12]), torch.float32)
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
